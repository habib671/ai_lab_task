# %% [markdown]
# <a href="https://colab.research.google.com/github/habib671/ai_lab_task/blob/main/Lab_Task_03(181_15_1907).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
course_list = []
choice = 'random'

def line():
    print('---------------------------')

def show_menu():
    line()
    print('MENU')
    line()
    print('1. Enroll a course')
    print('2. Unenroll a course')
    print('3. View your enrolled courses')
    print('4. Exit')
    line()
    choice = input('Enter your choice: ')
    return choice

while choice != '4':
    choice = show_menu()
    if choice == '1':
        course = input('Which course do you want to enroll? ')
        course_list.append(course)
        print('You are enrolled to this course: ', course,)
    elif choice == '2':
        course = input('Which course do you want to unenroll? ')
        if course in course_list:
            course_list.remove(course)
            print('You have successfully unenrolled from this course: ', course)
        else:
            print('Could not find any course named: ', course)
    elif choice == '3':
        print('Your enrolled courses for this semester:')
        for course in course_list:
            print(course)
    elif choice == '4':
        print('Goodbye!')
    else:
        print('Please enter one of 1, 2, 3 or 4')
# Out:
# ---------------------------
# MENU
# ---------------------------
# 1. Enroll a course
# 2. Unenroll a course
# 3. View your enrolled courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Which course do you want to enroll? CSE411
# You are enrolled to this course:  CSE411
# ---------------------------
# MENU
# ---------------------------
# 1. Enroll a course
# 2. Unenroll a course
# 3. View your enrolled courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Which course do you want to enroll? CSE412
# You are enrolled to this course:  CSE412
# ---------------------------
# MENU
# ---------------------------
# 1. Enroll a course
# 2. Unenroll a course
# 3. View your enrolled courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Which course do you want to enroll? CSE413
# You are enrolled to this course:  CSE413
# ---------------------------
# MENU
# ---------------------------
# 1. Enroll a course
# 2. Unenroll a course
# 3. View your enrolled courses
# 4. Exit
# ---------------------------
# Enter your choice: 3
# Your enrolled courses for this semester:
# CSE411
# CSE412
# CSE413
# ---------------------------
# MENU
# ---------------------------
# 1. Enroll a course
# 2. Unenroll a course
# 3. View your enrolled courses
# 4. Exit
# ---------------------------
# Enter your choice: 2
# Which course do you want to unenroll? CSE412
# You have successfully unenrolled from this course:  CSE412
# ---------------------------
# MENU
# ---------------------------
# 1. Enroll a course
# 2. Unenroll a course
# 3. View your enrolled courses
# 4. Exit
# ---------------------------
# Enter your choice: 3
# Your enrolled courses for this semester:
# CSE411
# CSE413
# ---------------------------
# MENU
# ---------------------------
# 1. Enroll a course
# 2. Unenroll a course
# 3. View your enrolled courses
# 4. Exit
# ---------------------------
# Enter your choice: 4
# Goodbye!
